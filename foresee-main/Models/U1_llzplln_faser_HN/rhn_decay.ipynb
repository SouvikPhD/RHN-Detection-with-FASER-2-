# %%
import sys
src_path = "/home/souvik/codes/foresee-main"
sys.path.append(src_path)

import numpy as np
import os
from matplotlib import pyplot as plt
import math
import random
from skhep.math.vectors import LorentzVector, Vector3D
from scipy import interpolate
from matplotlib import gridspec
import os, inspect

# %%
from src_modified.foresee import Foresee, Utility, Model
foresee = Foresee()

energy = "14"
modelname="U1_B-L_see"
model = Model(modelname, path="./")

# %%
sys.path.insert(1, os.path.join(os.path.dirname(os.path.realpath(
                inspect.getfile(inspect.currentframe()))), "/home/souvik/codes/darkcast_chiral/"))
import darkcast

# %%
model.add_production_2bodydecay(
    pid0 = "111",
    pid1 = "22",
    br = "2*0.99 * (coupling/0.303)**2 * pow(1.-pow(mass/self.masses('111'),2),3)",
#     br = "2*0.99 * (coupling)**2 * pow(1.-pow(mass/self.masses('111'),2),3)",
    generator = "EPOSLHC",
    energy = energy,
    nsample = 50,
)

model.add_production_2bodydecay(
    pid0 = "221",
    pid1 = "22",
    br = "2*0.25*0.39  * (coupling/0.303)**2 * pow(1.-pow(mass/self.masses('221'),2),3)",
#     br = "2*0.39 * (coupling)**2 * pow(1.-pow(mass/self.masses('221'),2),3)",
    generator = "EPOSLHC",
    energy = energy,
    nsample = 50, 
)

# %%
masses_brem = [ 
   0.01  ,  0.0126,  0.0158,  0.02  ,  0.0251,  0.0316,  0.0398,
   0.0501,  0.0631,  0.0794,  0.1   ,  0.1122,  0.1259,  0.1413,
   0.1585,  0.1778,  0.1995,  0.2239,  0.2512,  0.2818,  0.3162,
   0.3548,  0.3981,  0.4467,  0.5012,  0.5623,  0.6026,  0.631 ,
   0.6457,  0.6607,  0.6761,  0.6918,  0.7079,  0.7244,  0.7413,
   0.7586,  0.7762,  0.7943,  0.8128,  0.8318,  0.8511,  0.871 ,
   0.8913,  0.912 ,  0.9333,  0.955 ,  0.9772,  1.    ,  1.122 ,
   1.2589,  1.4125,  1.5849,  1.7783,  1.9953,  2.2387,  2.5119,
   2.8184,  3.1623,  3.9811,  5.0119,  6.3096,  7.9433, 10.    
]

model.add_production_direct(
    label = "Brem",
    energy = energy,
    condition = "1./0.3**2 * (p.pt<1)",
#     condition = "p.pt<1",
    coupling_ref=1,
    masses = masses_brem,
)

# %%
masses = np.logspace(-3, 1, 100)
masses = np.array(masses)
foresee.set_model(model=model)
# for mass in masses:
#     foresee.get_llp_spectrum(mass=mass, coupling=1, luminosity=3000, mincount=0,
#                                 do_plot=False, stat_cuts=None, save_file=True)

# %%
model.set_ctau_1d( folder = "model/",
    filename="ctau_RHN3.txt", xHs = [-2, -1, -0.5, 0, 0.5, 1, 2],
    coupling_ref=1
)
branchings = [
    ["e_e"     , "red"          , "solid" , r"ee"         , 0.050, 0.20],
    ["mu_mu"   , "orange"       , "solid" , r"$\mu\mu$"   , 0.170, 0.10],
    ["tau_tau"   , "orange"       , "solid" , r"$\mu\mu$"   , 1.8905, 0.10],

    ["nu_nu"   , "black"        , "dashed", r"$\nu\nu$"   , 0.110, 0.70],
    ["hadrons" , "blue"         , "solid" , r"hadrons"    , 0.410, 0.02],
    
    ["rhn" , "brown"         , "solid" , r"rhn"    , 0.110, 0.35]
]

model.set_br_1d(
    modes=[channel for channel,_,_,_,_,_ in branchings],
    finalstates=[[11,-11], [13,-13], [12,-12], None, None,None], folder = "model/br_RHN3/", xHs = [-2, -1, -0.5, 0, 0.5, 1, 2],
    filenames=[channel+".txt" for channel,_,_,_,_,_ in branchings],
)

# %%
# %%time
distance, selection, length, luminosity, channels = 475, "np.sqrt(x.x**2 + x.y**2)< 1", 5, 3000, ["e_e", "mu_mu", "tau_tau", "hadrons"]
energy, setup = '14', "default"
foresee.set_detector(distance=distance, selection=selection, length=length, luminosity=luminosity, channels=channels)

#get reach  
list_nevents = []    
#masses = np.logspace(-2, 1, 50)
for mass in masses:
    couplings, _, nevents, _, _  = foresee.get_events(nsample=1, mass=mass, xH=-2, model1="U1_X_2n", model0="B-L_boson", energy=energy,
                                    couplings = np.logspace(-9,-5,60), preselectioncuts="th<1/480",
                                                     mN1=1/3, mN2=1/3, mN3=1/3)
    list_nevents.append(nevents)  
        
#save results
np.save("model/results_RHN3/"+energy+"TeV_"+setup+"2n.npy",[masses,couplings,list_nevents])


# list_nevents = []    
# #masses = np.logspace(-2, 1, 50)
# for mass in masses:
#     couplings, _, nevents, _, _  = foresee.get_events(nsample=1, mass=mass, xH = -1, model1="U1_X_1n", model0="B-L_boson", energy=energy,
#                                     couplings = np.logspace(-9,-5,60), preselectioncuts="th<1/480",
#                                                      mN1=1/3, mN2=1/3, mN3=1/3)
#     list_nevents.append(nevents)  
        
# #save results
# np.save("model/results_RHN3/"+energy+"TeV_"+setup+"1n.npy",[masses,couplings,list_nevents])


# list_nevents = []    
# # masses = np.logspace(-2, 1, 50)
# for mass in masses:
#     couplings, _, nevents, _, _  = foresee.get_events(nsample=1, mass=mass,xH = -0.5, model1="U1_X_05n", model0="B-L_boson", energy=energy, 
#                                     couplings = np.logspace(-9,-5,60), preselectioncuts="th<1/480",
#                                                      mN1=1/3, mN2=1/3, mN3=1/3)
#     list_nevents.append(nevents)  
        
# #save results
# np.save("model/results_RHN3/"+energy+"TeV_"+setup+"05n.npy",[masses,couplings,list_nevents])

# list_nevents = []    
# #masses = np.logspace(-2, 1, 50)
# for mass in masses:
#     couplings, _, nevents, _, _  = foresee.get_events(nsample=1, mass=mass, xH = 0, model1="B-L_boson", model0="B-L_boson", energy=energy,
#                                     couplings = np.logspace(-9,-5,60), preselectioncuts="th<1/480",
#                                                      mN1=1/3, mN2=1/3, mN3=1/3)
#     list_nevents.append(nevents)  
    
# #save results
# np.save("model/results_RHN3/"+energy+"TeV_"+setup+"0.npy",[masses,couplings,list_nevents])


# list_nevents = []    
# # masses = np.logspace(-2, 1, 50)
# for mass in masses:
#     couplings, _, nevents, _, _  = foresee.get_events(nsample=1, mass=mass,xH = 0.5, model1="U1_X_05p", model0="B-L_boson", energy=energy, 
#                                     couplings = np.logspace(-9,-5,60), preselectioncuts="th<1/480",
#                                                      mN1=1/3, mN2=1/3, mN3=1/3)
#     list_nevents.append(nevents)  
        
# #save results
# np.save("model/results_RHN3/"+energy+"TeV_"+setup+"05p.npy",[masses,couplings,list_nevents])


# list_nevents = []    
# # masses = np.logspace(-2, 1, 50)
# for mass in masses:
#     couplings, _, nevents, _, _  = foresee.get_events(nsample=1, mass=mass,xH = 1, model1="U1_X_1p", model0="B-L_boson", energy=energy, 
#                                     couplings = np.logspace(-9,-5,60), preselectioncuts="th<1/480",
#                                                      mN1=1/3, mN2=1/3, mN3=1/3)
#     list_nevents.append(nevents)  
        
# #save results
# np.save("model/results_RHN3/"+energy+"TeV_"+setup+"1p.npy",[masses,couplings,list_nevents])


# #get reach  
# list_nevents = []    
# #masses = np.logspace(-2, 1, 50)
# for mass in masses:
#     couplings, _, nevents, _, _  = foresee.get_events(nsample=1, mass=mass, xH=2, model1="U1_X_2p", model0="B-L_boson", energy=energy,
#                                     couplings = np.logspace(-9,-5,60), preselectioncuts="th<1/480",
#                                                      mN1=1/3, mN2=1/3, mN3=1/3)
#     list_nevents.append(nevents)  
        
# #save results
# np.save("model/results_RHN3/"+energy+"TeV_"+setup+"2p.npy",[masses,couplings,list_nevents])
# Out:
# CPU times: user 1min 28s, sys: 31.8 ms, total: 1min 28s
# Wall time: 1min 28s

# %%
setups = [
         ["14TeV_default2n.npy",    r"$x_H = -2$"  , "purple", "solid", 0., 3],#*150/3000],
         # ["14TeV_default1n.npy",    r"$x_H = -1$"  , "blue", "solid", 0., 3],#*150/3000],
         # ["14TeV_default05n.npy",    r"$x_H = -0.5$"  , "green", "solid", 0., 3],#*150/3000],
         # ["14TeV_default0.npy",    r"$x_H = 0$"  , "orange", "solid", 0., 3],#*150/3000],
         # ["14TeV_default05p.npy",    r"$x_H = 0.5$"  , "red", "solid", 0., 3],#*150/3000],
         # ["14TeV_default1p.npy",    r"$x_H = 1$"  , "maroon", "solid", 0., 3],#*150/3000]]  
         # ["14TeV_default2p.npy",    r"$x_H = 2$"  , "purple", "solid", 0., 3]#*150/3000]]
]

for setup in setups:
    fig, ax = plt.subplots()
    filename, label, color, ls, alpha, level = setup
    masses,couplings,nsignals=np.load(model.modelpath+"model/results_RHN3/"+filename, allow_pickle=True, encoding='latin1')
    # m, c, n = masses,couplings,nsignals #changed
    m, c = np.meshgrid(masses, couplings)
    n = np.log10(np.array(nsignals).T+1e-20)
    ax.contour (m,c,n, levels=[np.log10(level)],colors=color, linestyles=ls, clabel=label)
    ax.plot([0],[0],label=label, color=color)
    ax.set_xscale("log")
    ax.set_yscale("log")
    ax.set_xlabel(r"$m_{Z'}$ [GeV]") 
    ax.set_ylabel(r"$g_X$")
    plt.rcParams["figure.figsize"]=(12,6)
    ax.set_xlim(1e-3, 10)
    ax.set_ylim(1e-9, 1e-5)
    ax.legend()
    ax.set_title(r"Z' long-lived, RHN long-lived: $m_N = m_{Z'}/3$")
# Out:
# /tmp/ipykernel_11831/25762296.py:18: UserWarning: The following kwargs were not used by contour: 'clabel'
#   ax.contour (m,c,n, levels=[np.log10(level)],colors=color, linestyles=ls, clabel=label)

# %%
model.set_ctau_1d( folder = "model/",
    filename="ctau_RHN3_phi4.txt", xHs = [-2, -1, -0.5, 0, 0.5, 1, 2],
    coupling_ref=1
)
branchings = [
    ["e_e"     , "red"          , "solid" , r"ee"         , 0.050, 0.20],
    ["mu_mu"   , "orange"       , "solid" , r"$\mu\mu$"   , 0.170, 0.10],
    ["tau_tau"   , "orange"       , "solid" , r"$\mu\mu$"   , 1.8905, 0.10],

    ["nu_nu"   , "black"        , "dashed", r"$\nu\nu$"   , 0.110, 0.70],
    ["hadrons" , "blue"         , "solid" , r"hadrons"    , 0.410, 0.02],
    
    ["rhn" , "brown"         , "solid" , r"rhn"    , 0.110, 0.35]
]

model.set_br_1d(
    modes=[channel for channel,_,_,_,_,_ in branchings],
    finalstates=[[11,-11], [13,-13], [12,-12], None, None,None], folder = "model/br_RHN3_phi4/", xHs = [-2, -1, -0.5, 0, 0.5, 1, 2],
    filenames=[channel+".txt" for channel,_,_,_,_,_ in branchings],
)

# %%
# %%time
distance, selection, length, luminosity, channels = 475, "np.sqrt(x.x**2 + x.y**2)< 1", 5, 3000, ["e_e", "mu_mu", "tau_tau", "hadrons"]
energy, setup = '14', "default"
foresee.set_detector(distance=distance, selection=selection, length=length, luminosity=luminosity, channels=channels)

#get reach  
list_nevents = []    
#masses = np.logspace(-2, 1, 50)
for mass in masses:
    couplings, _, nevents, _, _  = foresee.get_events(nsample=1, mass=mass, xH=-2, model1="U1_X_phi4_2n", model0="B-L_boson", energy=energy,
                                    couplings = np.logspace(-9,-5,60), preselectioncuts="th<1/480",
                                                     mN1=1/3, mN2=1/3, mN3=1/3)
    list_nevents.append(nevents)  
        
#save results
np.save("model/results_RHN3_phi4/"+energy+"TeV_"+setup+"2n.npy",[masses,couplings,list_nevents])


list_nevents = []    
#masses = np.logspace(-2, 1, 50)
for mass in masses:
    couplings, _, nevents, _, _  = foresee.get_events(nsample=1, mass=mass, xH = -1, model1="U1_X_phi4_1n", model0="B-L_boson", energy=energy,
                                    couplings = np.logspace(-9,-5,60), preselectioncuts="th<1/480",
                                                     mN1=1/3, mN2=1/3, mN3=1/3)
    list_nevents.append(nevents)  
        
#save results
np.save("model/results_RHN3_phi4/"+energy+"TeV_"+setup+"1n.npy",[masses,couplings,list_nevents])


list_nevents = []    
# masses = np.logspace(-2, 1, 50)
for mass in masses:
    couplings, _, nevents, _, _  = foresee.get_events(nsample=1, mass=mass,xH = -0.5, model1="U1_X_phi4_05n", model0="B-L_boson", energy=energy, 
                                    couplings = np.logspace(-9,-5,60), preselectioncuts="th<1/480",
                                                     mN1=1/3, mN2=1/3, mN3=1/3)
    list_nevents.append(nevents)  
        
#save results
np.save("model/results_RHN3_phi4/"+energy+"TeV_"+setup+"05n.npy",[masses,couplings,list_nevents])

list_nevents = []    
#masses = np.logspace(-2, 1, 50)
for mass in masses:
    couplings, _, nevents, _, _  = foresee.get_events(nsample=1, mass=mass, xH = 0, model1="phi4_B-L_boson", model0="B-L_boson", energy=energy,
                                    couplings = np.logspace(-9,-5,60), preselectioncuts="th<1/480",
                                                     mN1=1/3, mN2=1/3, mN3=1/3)
    list_nevents.append(nevents)  
    
#save results
np.save("model/results_RHN3_phi4/"+energy+"TeV_"+setup+"0.npy",[masses,couplings,list_nevents])


list_nevents = []    
# masses = np.logspace(-2, 1, 50)
for mass in masses:
    couplings, _, nevents, _, _  = foresee.get_events(nsample=1, mass=mass,xH = 0.5, model1="U1_X_phi4_05p", model0="B-L_boson", energy=energy, 
                                    couplings = np.logspace(-9,-5,60), preselectioncuts="th<1/480",
                                                     mN1=1/3, mN2=1/3, mN3=1/3)
    list_nevents.append(nevents)  
        
#save results
np.save("model/results_RHN3_phi4/"+energy+"TeV_"+setup+"05p.npy",[masses,couplings,list_nevents])


list_nevents = []    
# masses = np.logspace(-2, 1, 50)
for mass in masses:
    couplings, _, nevents, _, _  = foresee.get_events(nsample=1, mass=mass,xH = 1, model1="U1_X_phi4_1p", model0="B-L_boson", energy=energy, 
                                    couplings = np.logspace(-9,-5,60), preselectioncuts="th<1/480",
                                                     mN1=1/3, mN2=1/3, mN3=1/3)
    list_nevents.append(nevents)  
        
#save results
np.save("model/results_RHN3_phi4/"+energy+"TeV_"+setup+"1p.npy",[masses,couplings,list_nevents])


#get reach  
list_nevents = []    
#masses = np.logspace(-2, 1, 50)
for mass in masses:
    couplings, _, nevents, _, _  = foresee.get_events(nsample=1, mass=mass, xH=2, model1="U1_X_phi4_2p", model0="B-L_boson", energy=energy,
                                    couplings = np.logspace(-9,-5,60), preselectioncuts="th<1/480",
                                                     mN1=1/3, mN2=1/3, mN3=1/3)
    list_nevents.append(nevents)  
        
#save results
np.save("model/results_RHN3_phi4/"+energy+"TeV_"+setup+"2p.npy",[masses,couplings,list_nevents])
# Out:
# /home/souvik/anaconda3/lib/python3.11/site-packages/numpy/lib/npyio.py:521: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)
# CPU times: user 18min 36s, sys: 735 ms, total: 18min 36s
# Wall time: 18min 41s

# %%
setups = [
         ["14TeV_default2n.npy",    r"$x_H = -2$"  , "purple", "solid", 0., 3],#*150/3000],
         ["14TeV_default1n.npy",    r"$x_H = -1$"  , "blue", "solid", 0., 3],#*150/3000],
         ["14TeV_default05n.npy",    r"$x_H = -0.5$"  , "green", "solid", 0., 3],#*150/3000],
         ["14TeV_default0.npy",    r"$x_H = 0$"  , "orange", "solid", 0., 3],#*150/3000],
         ["14TeV_default05p.npy",    r"$x_H = 0.5$"  , "red", "solid", 0., 3],#*150/3000],
         ["14TeV_default1p.npy",    r"$x_H = 1$"  , "maroon", "solid", 0., 3],#*150/3000]]  
         ["14TeV_default2p.npy",    r"$x_H = 2$"  , "purple", "solid", 0., 3]#*150/3000]]
]

for setup in setups:
    fig, ax = plt.subplots()
    filename, label, color, ls, alpha, level = setup
    masses,couplings,nsignals=np.load(model.modelpath+"model/results_RHN3_phi4/"+filename, allow_pickle=True, encoding='latin1')
    # m, c, n = masses,couplings,nsignals #changed
    m, c = np.meshgrid(masses, couplings)
    n = np.log10(np.array(nsignals).T+1e-20)
    ax.contour (m,c,n, levels=[np.log10(level)],colors=color, linestyles=ls, clabel=label)
    ax.plot([0],[0],label=label, color=color)
    ax.set_xscale("log")
    ax.set_yscale("log")
    ax.set_xlabel(r"$m_{Z'}$ [GeV]") 
    ax.set_ylabel(r"$g_X$")
    plt.rcParams["figure.figsize"]=(8,6)
    ax.set_xlim(1e-3, 10)
    ax.set_ylim(1e-9, 1e-5)
    ax.legend()
    ax.set_title(r"Z' long-lived, RHN long-lived: $m_N = m_{Z'}/3$")
# Out:
# /tmp/ipykernel_7876/3526529552.py:18: UserWarning: The following kwargs were not used by contour: 'clabel'
#   ax.contour (m,c,n, levels=[np.log10(level)],colors=color, linestyles=ls, clabel=label)
